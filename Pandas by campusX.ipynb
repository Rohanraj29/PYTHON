# %% [markdown]
# # SERIES FROM LIST

# %%
import numpy as np
import pandas as pd
name=["Rahul","Rohan","Sakshi","Pihu"]
a=pd.Series(name)
a
# Out:
# 0     Rahul
# 1     Rohan
# 2    Sakshi
# 3      Pihu
# dtype: object

# %% [markdown]
# # SERIES FROM INTEGER

# %%
import pandas as pd
import numpy as np
age=[19,18,16,15]
a=pd.Series(age)
a
# Out:
# 0    19
# 1    18
# 2    16
# 3    15
# dtype: int64

# %% [markdown]
# # creating a custom index and also provides a name to our series.

# %%
import numpy as np
import pandas as pd
marks=[92,94,98,96,89]
subject=["English","Maths","Hindi","Science","Computer"]
b=pd.Series(marks,index=subject,name="Rahul Marks in 10th")
b
# Out:
# English     92
# Maths       94
# Hindi       98
# Science     96
# Computer    89
# Name: Rahul Marks in 10th, dtype: int64

# %% [markdown]
# # series from dicitionary.

# %%
import numpy as np
import pandas as pd
details={
    "name": "Rahul Raj",
    "age": 19,
    "gender": "Male",
    "city": "Muzaffarpur"
}
a=pd.Series(details)
a
# Out:
# name        Rahul Raj
# age                19
# gender           Male
# city      Muzaffarpur
# dtype: object

# %% [markdown]
# # series attributes.

# %% [markdown]
# # size

# %%
a.size
# Out:
# 4

# %% [markdown]
# # dtype

# %%
b.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # name

# %%
b.name
# Out:
# 'Rahul Marks in 10th'

# %% [markdown]
# # is_unique

# %%
b.is_unique
# Out:
# True

# %% [markdown]
# # index

# %%
b.index
# Out:
# Index(['English', 'Maths', 'Hindi', 'Science', 'Computer'], dtype='object')

# %% [markdown]
# # values

# %%
b.values
# Out:
# array([92, 94, 98, 96, 89], dtype=int64)

# %% [markdown]
# # series using read_csv

# %%
# 1 column
a=pd.read_csv("C:\\Users\\rohan\\Downloads\\subs.csv")
s=a.squeeze()
a
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
# 2 column
vk=pd.read_csv("C:\\Users\\rohan\\Downloads\\kohli_ipl.csv",index_col="match_no")
r=vk.squeeze()
vk
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1
# ...        ...
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7
#
# [215 rows x 1 columns]

# %%
movie=pd.read_csv(r"C:\Users\rohan\Downloads\bollywood.csv",index_col="movie")
m=movie.squeeze()
movie
# Out:
#                                                   lead
# movie
# Uri: The Surgical Strike                 Vicky Kaushal
# Battalion 609                              Vicky Ahuja
# The Accidental Prime Minister (film)       Anupam Kher
# Why Cheat India                          Emraan Hashmi
# Evening Shadows                       Mona Ambegaonkar
# ...                                                ...
# Hum Tumhare Hain Sanam                  Shah Rukh Khan
# Aankhen (2002 film)                   Amitabh Bachchan
# Saathiya (film)                           Vivek Oberoi
# Company (film)                              Ajay Devgn
# Awara Paagal Deewana                      Akshay Kumar
#
# [1500 rows x 1 columns]

# %% [markdown]
# # csv attributes

# %% [markdown]
# # head()

# %%
vk.head()
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13
# 4           12
# 5            1

# %% [markdown]
# # tail()

# %%
vk.tail()
# Out:
#           runs
# match_no
# 211          0
# 212         20
# 213         73
# 214         25
# 215          7

# %% [markdown]
# # sample()

# %%
vk.sample()
# Out:
#           runs
# match_no
# 153         48

# %% [markdown]
# # value_counts():- kisi v value ka frequency count krna hai data me then we use value_counts()

# %%
movie.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Kashmira Shah        1
# Kartik Elangovan     1
# Karisma Kapoor       1
# Karan Sharma         1
# Zulfi Sayed          1
# Name: count, Length: 566, dtype: int64

# %% [markdown]
# # sort_index()

# %%
vk.sort_index(ascending=False,inplace=True)
vk
# Out:
#           runs
# match_no
# 215          7
# 214         25
# 213         73
# 212         20
# 211          0
# ...        ...
# 5            1
# 4           12
# 3           13
# 2           23
# 1            1
#
# [215 rows x 1 columns]

# %% [markdown]
# # series maths methods

# %% [markdown]
# # count:- it does not count the null values whereas size counts the null values

# %%
vk.count()
# Out:
# runs    215
# dtype: int64

# %% [markdown]
# # sum

# %%
vk.sum()
# Out:
# runs    6634
# dtype: int64

# %% [markdown]
# # product

# %%
vk.product()
# Out:
# runs    0
# dtype: int64

# %% [markdown]
# # mean()

# %%
vk.mean()
# Out:
# runs    30.855814
# dtype: float64

# %% [markdown]
# # meadian()

# %%
vk.median()
# Out:
# runs    24.0
# dtype: float64

# %% [markdown]
# # mode()

# %%
movie.mode()
# Out:
#            lead
# 0  Akshay Kumar

# %% [markdown]
# # min()

# %%
vk.min()
# Out:
# runs    0
# dtype: int64

# %% [markdown]
# # max()

# %%
vk.max()
# Out:
# runs    113
# dtype: int64

# %% [markdown]
# # describe():- gives the quick overview of data.

# %%
vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %% [markdown]
# # slicing in series.

# %%
vk[0:8]
# Out:
#           runs
# match_no
# 215          7
# 214         25
# 213         73
# 212         20
# 211          0
# 210         30
# 209         58
# 208          9

# %% [markdown]
# # series with python functionalities
# # type,len,max,min

# %%
print(type(vk))
print(len(vk))
print(max(vk))
print(min(vk))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 215
# runs
# runs

# %% [markdown]
# # type conversion

# %%
print(list(b))
print(dict(b))
# Out:
# [92, 94, 98, 96, 89]
# {'English': 92, 'Maths': 94, 'Hindi': 98, 'Science': 96, 'Computer': 89}

# %% [markdown]
# # membership operator

# %%
"Vicky Kaushal" in movie.values
# Out:
# True

# %%
"Uri: The Surgical Strike" in movie.index
# Out:
# True

# %% [markdown]
# # looping

# %%
for i in movie.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
for i in movie.values:
    print(i)
# Out:
# ['Vicky Kaushal']
# ['Vicky Ahuja']
# ['Anupam Kher']
# ['Emraan Hashmi']
# ['Mona Ambegaonkar']
# ['Geetika Vidya Ohlyan']
# ['Arshad Warsi']
# ['Radhika Apte']
# ['Kangana Ranaut']
# ['Nawazuddin Siddiqui']
# ['Ali Asgar']
# ['Ranveer Singh']
# ['Prit Kamani']
# ['Ajay Devgn']
# ['Sushant Singh Rajput']
# ['Amitabh Bachchan']
# ['Abhimanyu Dasani']
# ['Talha Arshad Reshi']
# ['Nawazuddin Siddiqui']
# ['Garima Agarwal']
# ['Rasika Agashe']
# ['Barun Sobti']
# ['Akshay Kumar']
# ['Zaheer Iqbal']
# ['Vidyut Jammwal']
# ['Deepika Amin']
# ['Manav Kaul']
# ['Naseeruddin Shah']
# ['Varun Dhawan']
# ['Shreyas Talpade']
# ['Tiger Shroff']
# ['Boman Irani']
# ['Ajay Devgn']
# ['Arjun Kapoor']
# ['Gavie Chahal']
# ['Prabhu Deva']
# ['Shahid Kapoor']
# ['Ayushmann Khurrana']
# ['Anupam Kher']
# ['Karanvir Bohra']
# ['Hrithik Roshan']
# ['Jimmy Sheirgill']
# ['John Abraham']
# ['Rishi Kapoor']
# ['Kangana Ranaut']
# ['Natalia Janoszek']
# ['Diljit Dosanjh']
# ['Sidharth Malhotra']
# ...

# %% [markdown]
# # arithmetic operator

# %%
b
# Out:
# English     92
# Maths       94
# Hindi       98
# Science     96
# Computer    89
# Name: Rahul Marks in 10th, dtype: int64

# %%
100-b
# Out:
# English      8
# Maths        6
# Hindi        2
# Science      4
# Computer    11
# Name: Rahul Marks in 10th, dtype: int64

# %%
vk>18
# Out:
#            runs
# match_no
# 1         False
# 2          True
# 3         False
# 4         False
# 5         False
# ...         ...
# 211       False
# 212        True
# 213        True
# 214        True
# 215       False
#
# [215 rows x 1 columns]

# %% [markdown]
# # boolean indexing on series

# %%
# Find no of 50's and 100's scored by kohli
vk[vk>50].size
# Out:
# 215

# %%
vk[vk==0].size
# Out:
# 215

# %% [markdown]
# # plotting graph on series

# %%
a.plot()
# Out:
# <Axes: >

# %%
movie.value_counts().head(15).plot(kind="bar")
# Out:
# <Axes: xlabel='lead'>
